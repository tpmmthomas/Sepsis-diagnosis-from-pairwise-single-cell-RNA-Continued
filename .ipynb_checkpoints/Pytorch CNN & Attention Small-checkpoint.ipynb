# %%
# importing the libraries
import pandas as pd
import numpy as np
import os

# for reading and displaying images
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline

# for creating validation set
from sklearn.model_selection import train_test_split

# for evaluating the model
from sklearn.metrics import accuracy_score
from tqdm import tqdm

# PyTorch libraries and modules
import torch
from torch.autograd import Variable
import torch.nn as nn
from torch.optim import Adam, SGD
from torch.utils.data import Dataset, DataLoader

#Transformers
from module import *

# %%
# Load training data set (small amount to test if it works first)

xtrain = r"data/training_sample_NoSparse.csv.gz"
ytrain = r"data/training_label_NoSparse.csv.gz"
xtest = r"data/testing_sample_NoSparse.csv.gz"
ytest = r"data/testing_label_NoSparse.csv.gz"

# %%
#check balance
samplesdf = pd.DataFrame()
for df in  pd.read_csv(ytrain,compression ="gzip",delimiter=',', chunksize = 10000, header=0):
    samplesdf = samplesdf.append(df)
y_train = samplesdf.to_numpy()

num0 = 0
num1 = 0
for x in y_train:
    if x == 0:
        num0 = num0 + 1
    else:
        num1 = num1 + 1
num0,num1 #checking if it is balanced
# Out:
# (15161, 14094)

# %%
df = pd.read_csv(xtrain,compression ="gzip",delimiter=',', nrows=123, header=0)
x_train = df.to_numpy()
print(x_train)
# Out:
# [[0.   0.   0.   ... 3.11 0.   3.69]
#  [0.   0.   0.   ... 3.16 0.   3.33]
#  [0.   0.   0.   ... 2.98 0.   3.64]
#  ...
#  [1.39 0.   0.   ... 1.95 0.   3.57]
#  [0.   2.08 0.   ... 2.71 0.   3.09]
#  [0.   0.   0.   ... 3.12 0.   2.85]]

# %%
class Dataset(Dataset):

    def __init__(self,samples,labels,numrows):

        self.data = pd.read_csv(samples,compression ="gzip",delimiter=',', nrows = numrows, header=0)
        self.label = pd.read_csv(labels,compression ="gzip",delimiter=',', nrows = numrows, header=0)
        
    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        rna = self.data.iloc[idx]
        seplb = self.label.iloc[idx]
        rna = np.array([rna])
        seplb = np.array([seplb])
        rna = rna.astype('double').reshape(-1,3273)
        i = 0
        d = np.zeros((len(seplb),2))
        for x in seplb:
            if x == 0:
                d[i] = [1,0]
            else:
                d[i] = [0,1]
        sample = {'rna': rna, 'label': d}

        return sample

# %%
train_dataset = Dataset(samples=xtrain,labels=ytrain,numrows = 29255)
test_dataset = Dataset(samples = xtest,labels = ytest,numrows = 3241)

# %%
# Hyper Parameters
EPOCH = 20             # train the training data n times, to save time, we just train 1 epoch
LR = 0.0001              # learning rate
batch_size = 32
wd = LR / EPOCH

# %%
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %%
class CNN_Trans(nn.Module):
    def __init__(self):
        super(CNN_Trans, self).__init__()
        self.conv1 = nn.Sequential(         # input shape (x,1, 8949)
            nn.Conv1d(
                in_channels=1,              # input height
                out_channels=4,            # n_filters
                kernel_size=3,              # filter size
                stride=1,                   # filter movement/step
                padding=1,                  # if want same width and length of this image after con2d, padding=(kernel_size-1)/2 if stride=1
            ),                              # output shape (x,64,8949)
            nn.BatchNorm1d(4),
            nn.ReLU(),                      # activation
        )
        self.conv2 = nn.Sequential(         # input shape (x,64, 8949)
            nn.Conv1d(4,4,3,1,1),            
            nn.ReLU(),  
            nn.Dropout(p=0.1),
            nn.MaxPool1d(kernel_size =2, stride=2,ceil_mode = True),                # output shape (x,64,4478)
        )
        self.conv3 = nn.Sequential(         # input shape (x,64,4478)
            nn.Conv1d(4, 8, 3, 1, 1),     # output shape (x,128,4478)
            nn.ReLU(),                      # activation
            nn.MaxPool1d(kernel_size =2, stride=2,ceil_mode = True),                # output shape (x,128,2238)
        )
        self.enc = nn.Sequential(
            SAB(dim_in=6552, dim_out=64, num_heads=4),
            SAB(dim_in=64, dim_out=64, num_heads=4),
        )
        self.dec = nn.Sequential(
            PMA(dim=64, num_heads=4, num_seeds=1),
            nn.Linear(in_features=64, out_features=2),
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = x.view(x.size(0), -1)
        x = x.reshape(-1,1,6552)
        x = self.enc(x)
        x = self.dec(x)
        return x.squeeze(-1)

# %%
cnntrans = CNN_Trans()
optimizer = torch.optim.Adam(cnntrans.parameters(), lr=LR)   
loss_func = nn.L1Loss()                      
if torch.cuda.is_available():
    loss_func = loss_func.cuda()
    cnntrans = cnntrans.cuda()
cnntrans = cnntrans.double()
print(cnntrans)
# Out:
# CNN_Trans(
#   (conv1): Sequential(
#     (0): Conv1d(1, 4, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv2): Sequential(
#     (0): Conv1d(4, 4, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   )
#   (conv3): Sequential(
#     (0): Conv1d(4, 8, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   )
#   (enc): Sequential(
#     (0): SAB(
#       (mab): MAB(
#         (fc_q): Linear(in_features=6552, out_features=64, bias=True)
#         (fc_k): Linear(in_features=6552, out_features=64, bias=True)
#         (fc_v): Linear(in_features=6552, out_features=64, bias=True)
#         (fc_o): Linear(in_features=64, out_features=64, bias=True)
#       )
#     )
#     (1): SAB(
#       (mab): MAB(
#         (fc_q): Linear(in_features=64, out_features=64, bias=True)
#         (fc_k): Linear(in_features=64, out_features=64, bias=True)
#         (fc_v): Linear(in_features=64, out_features=64, bias=True)
#         (fc_o): Linear(in_features=64, out_features=64, bias=True)
#       )
#     )
#   )
#   (dec): Sequential(
#     (0): PMA(
#       (mab): MAB(
#         (fc_q): Linear(in_features=64, out_features=64, bias=True)
#         (fc_k): Linear(in_features=64, out_features=64, bias=True)
#         (fc_v): Linear(in_features=64, out_features=64, bias=True)
#         (fc_o): Linear(in_features=64, out_features=64, bias=True)
#       )
#     )
#     (1): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %%
def test(model):
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for batch in train_loader:
            rna,labels = batch["rna"], batch["label"] 
            if torch.cuda.is_available():
                rna = rna.cuda()
                labels = labels.cuda()
            labels = labels.reshape(-1,2)
            outputs = model(rna)
            outputs = outputs.reshape(-1,2)
            _, predicted = torch.max(outputs.data, 1)
            _, labels = torch.max(labels.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
           # print(total,correct)

        print('Train Accuracy of the model on the train rna: {} %'.format((correct / total) * 100))
    with torch.no_grad():
        correct = 0
        total = 0
        for batch in test_loader:
            rna,labels = batch["rna"], batch["label"] 
            if torch.cuda.is_available():
                rna = rna.cuda()
                labels = labels.cuda()
            labels = labels.reshape(-1,2)
            outputs = model(rna)
            outputs = outputs.reshape(-1,2)
            _, predicted = torch.max(outputs.data, 1)
            _, labels = torch.max(labels.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    #print(total,correct)

        print('Test Accuracy of the model on the test rna: {} %'.format((correct / total) * 100))

# %%
def train(model): 
    total_step = len(train_loader)
    num_epoch = EPOCH
    for epoch in range(num_epoch):
        model.train()
        for i, batch in enumerate(train_loader):
            # Run the forward pass
            rna,labels = batch["rna"], batch["label"] 
            if torch.cuda.is_available():
                rna = rna.cuda()
                labels = labels.cuda()
            outputs = model(rna)
            labels = labels.long()
            #print(outputs)
            outputs = outputs.reshape(-1,2)
            labels = labels.reshape(-1,2)
            loss = loss_func(outputs, labels)
            train_losses.append(loss.item())

            # Backprop and perform Adam optimisation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Track the accuracy
            total = labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            _, labels = torch.max(labels.data, 1)
            correct = (predicted == labels).sum().item()
            train_acc.append(correct / total)
            if i % 100 == 0:
                print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                        .format(epoch + 1, num_epoch , i + 1, total_step, loss.item(),
                                (correct / total) * 100))
        test(model)

# %%
train_losses = []
train_acc = []
test_acc = []
train(cnntrans)
# Out:
# Epoch [1/20], Step [1/915], Loss: 0.5334, Accuracy: 43.75%
# Epoch [1/20], Step [101/915], Loss: 0.4039, Accuracy: 62.50%
# Epoch [1/20], Step [201/915], Loss: 0.3767, Accuracy: 65.62%
# Epoch [1/20], Step [301/915], Loss: 0.3871, Accuracy: 65.62%
# Epoch [1/20], Step [401/915], Loss: 0.2962, Accuracy: 75.00%
# Epoch [1/20], Step [501/915], Loss: 0.3355, Accuracy: 65.62%
# Epoch [1/20], Step [601/915], Loss: 0.4423, Accuracy: 59.38%
# Epoch [1/20], Step [701/915], Loss: 0.2011, Accuracy: 87.50%
# Epoch [1/20], Step [801/915], Loss: 0.2286, Accuracy: 84.38%
# Epoch [1/20], Step [901/915], Loss: 0.2715, Accuracy: 75.00%
# Train Accuracy of the model on the train rna: 78.07212442317552 %
# Test Accuracy of the model on the test rna: 76.27275532243135 %
# Epoch [2/20], Step [1/915], Loss: 0.3763, Accuracy: 65.62%
# Epoch [2/20], Step [101/915], Loss: 0.2717, Accuracy: 71.88%
# Epoch [2/20], Step [201/915], Loss: 0.2144, Accuracy: 81.25%
# Epoch [2/20], Step [301/915], Loss: 0.1844, Accuracy: 90.62%
# Epoch [2/20], Step [401/915], Loss: 0.2454, Accuracy: 68.75%
# Epoch [2/20], Step [501/915], Loss: 0.1063, Accuracy: 93.75%
# Epoch [2/20], Step [601/915], Loss: 0.1664, Accuracy: 87.50%
# Epoch [2/20], Step [701/915], Loss: 0.2743, Accuracy: 78.12%
# Epoch [2/20], Step [801/915], Loss: 0.2169, Accuracy: 78.12%
# Epoch [2/20], Step [901/915], Loss: 0.2096, Accuracy: 84.38%
# Train Accuracy of the model on the train rna: 74.05229875235003 %
# Test Accuracy of the model on the test rna: 72.87874112928108 %
# Epoch [3/20], Step [1/915], Loss: 0.2980, Accuracy: 68.75%
# Epoch [3/20], Step [101/915], Loss: 0.2210, Accuracy: 81.25%
# Epoch [3/20], Step [201/915], Loss: 0.1800, Accuracy: 84.38%
# Epoch [3/20], Step [301/915], Loss: 0.2026, Accuracy: 84.38%
# Epoch [3/20], Step [401/915], Loss: 0.2828, Accuracy: 75.00%
# Epoch [3/20], Step [501/915], Loss: 0.2005, Accuracy: 90.62%
# Epoch [3/20], Step [601/915], Loss: 0.2260, Accuracy: 78.12%
# Epoch [3/20], Step [701/915], Loss: 0.2059, Accuracy: 81.25%
# Epoch [3/20], Step [801/915], Loss: 0.1492, Accuracy: 84.38%
# Epoch [3/20], Step [901/915], Loss: 0.3079, Accuracy: 68.75%
# Train Accuracy of the model on the train rna: 81.00837463681422 %
# Test Accuracy of the model on the test rna: 77.69207034865782 %
# Epoch [4/20], Step [1/915], Loss: 0.2623, Accuracy: 75.00%
# Epoch [4/20], Step [101/915], Loss: 0.0757, Accuracy: 93.75%
# Epoch [4/20], Step [201/915], Loss: 0.2002, Accuracy: 87.50%
# Epoch [4/20], Step [301/915], Loss: 0.1700, Accuracy: 84.38%
# Epoch [4/20], Step [401/915], Loss: 0.2454, Accuracy: 75.00%
# Epoch [4/20], Step [501/915], Loss: 0.2879, Accuracy: 71.88%
# Epoch [4/20], Step [601/915], Loss: 0.1732, Accuracy: 84.38%
# Epoch [4/20], Step [701/915], Loss: 0.2425, Accuracy: 78.12%
# Epoch [4/20], Step [801/915], Loss: 0.3098, Accuracy: 68.75%
# Epoch [4/20], Step [901/915], Loss: 0.2578, Accuracy: 75.00%
# Train Accuracy of the model on the train rna: 81.23397709793197 %
# Test Accuracy of the model on the test rna: 77.81548904659056 %
# Epoch [5/20], Step [1/915], Loss: 0.1297, Accuracy: 87.50%
# Epoch [5/20], Step [101/915], Loss: 0.2186, Accuracy: 81.25%
# Epoch [5/20], Step [201/915], Loss: 0.1470, Accuracy: 90.62%
# Epoch [5/20], Step [301/915], Loss: 0.2677, Accuracy: 71.88%
# Epoch [5/20], Step [401/915], Loss: 0.2214, Accuracy: 81.25%
# Epoch [5/20], Step [501/915], Loss: 0.2560, Accuracy: 75.00%
# Epoch [5/20], Step [601/915], Loss: 0.1893, Accuracy: 84.38%
# Epoch [5/20], Step [701/915], Loss: 0.2204, Accuracy: 81.25%
# Epoch [5/20], Step [801/915], Loss: 0.2004, Accuracy: 81.25%
# Epoch [5/20], Step [901/915], Loss: 0.1199, Accuracy: 90.62%
# Train Accuracy of the model on the train rna: 81.4493249017262 %
# Test Accuracy of the model on the test rna: 78.00061709348967 %
# Epoch [6/20], Step [1/915], Loss: 0.1372, Accuracy: 87.50%
# Epoch [6/20], Step [101/915], Loss: 0.3054, Accuracy: 68.75%
# Epoch [6/20], Step [201/915], Loss: 0.1090, Accuracy: 90.62%
# Epoch [6/20], Step [301/915], Loss: 0.3046, Accuracy: 71.88%
# Epoch [6/20], Step [401/915], Loss: 0.1743, Accuracy: 84.38%
# Epoch [6/20], Step [501/915], Loss: 0.2597, Accuracy: 78.12%
# Epoch [6/20], Step [601/915], Loss: 0.3352, Accuracy: 62.50%
# Epoch [6/20], Step [701/915], Loss: 0.2265, Accuracy: 78.12%
# Epoch [6/20], Step [801/915], Loss: 0.1717, Accuracy: 84.38%
# Epoch [6/20], Step [901/915], Loss: 0.1539, Accuracy: 84.38%
# Train Accuracy of the model on the train rna: 82.26969748760895 %
# Test Accuracy of the model on the test rna: 78.1240357914224 %
# Epoch [7/20], Step [1/915], Loss: 0.2402, Accuracy: 75.00%
# Epoch [7/20], Step [101/915], Loss: 0.2601, Accuracy: 71.88%
# Epoch [7/20], Step [201/915], Loss: 0.2541, Accuracy: 75.00%
# Epoch [7/20], Step [301/915], Loss: 0.2882, Accuracy: 71.88%
# Epoch [7/20], Step [401/915], Loss: 0.3266, Accuracy: 68.75%
# Epoch [7/20], Step [501/915], Loss: 0.1715, Accuracy: 87.50%
# Epoch [7/20], Step [601/915], Loss: 0.2149, Accuracy: 81.25%
# Epoch [7/20], Step [701/915], Loss: 0.2186, Accuracy: 78.12%
# Epoch [7/20], Step [801/915], Loss: 0.1793, Accuracy: 84.38%
# Epoch [7/20], Step [901/915], Loss: 0.1178, Accuracy: 90.62%
# Train Accuracy of the model on the train rna: 84.0266621090412 %
# Test Accuracy of the model on the test rna: 79.23480407281703 %
# Epoch [8/20], Step [1/915], Loss: 0.1796, Accuracy: 84.38%
# Epoch [8/20], Step [101/915], Loss: 0.2303, Accuracy: 78.12%
# Epoch [8/20], Step [201/915], Loss: 0.3052, Accuracy: 68.75%
# Epoch [8/20], Step [301/915], Loss: 0.2261, Accuracy: 78.12%
# Epoch [8/20], Step [401/915], Loss: 0.1850, Accuracy: 81.25%
# Epoch [8/20], Step [501/915], Loss: 0.2257, Accuracy: 78.12%
# Epoch [8/20], Step [601/915], Loss: 0.0822, Accuracy: 93.75%
# Epoch [8/20], Step [701/915], Loss: 0.2058, Accuracy: 78.12%
# Epoch [8/20], Step [801/915], Loss: 0.2854, Accuracy: 75.00%
# Epoch [8/20], Step [901/915], Loss: 0.1589, Accuracy: 84.38%
# Train Accuracy of the model on the train rna: 82.94308665185439 %
# Test Accuracy of the model on the test rna: 78.40172786177105 %
# Epoch [9/20], Step [1/915], Loss: 0.0844, Accuracy: 90.62%
# Epoch [9/20], Step [101/915], Loss: 0.3673, Accuracy: 62.50%
# Epoch [9/20], Step [201/915], Loss: 0.1300, Accuracy: 87.50%
# Epoch [9/20], Step [301/915], Loss: 0.2027, Accuracy: 81.25%
# Epoch [9/20], Step [401/915], Loss: 0.1736, Accuracy: 84.38%
# Epoch [9/20], Step [501/915], Loss: 0.1364, Accuracy: 90.62%
# Epoch [9/20], Step [601/915], Loss: 0.2844, Accuracy: 71.88%
# Epoch [9/20], Step [701/915], Loss: 0.1753, Accuracy: 81.25%
# Epoch [9/20], Step [801/915], Loss: 0.2203, Accuracy: 78.12%
# Epoch [9/20], Step [901/915], Loss: 0.2288, Accuracy: 78.12%
# Train Accuracy of the model on the train rna: 84.89147154332592 %
# Test Accuracy of the model on the test rna: 79.6976241900648 %
# Epoch [10/20], Step [1/915], Loss: 0.0834, Accuracy: 93.75%
# Epoch [10/20], Step [101/915], Loss: 0.1790, Accuracy: 84.38%
# Epoch [10/20], Step [201/915], Loss: 0.2849, Accuracy: 71.88%
# Epoch [10/20], Step [301/915], Loss: 0.2234, Accuracy: 78.12%
# Epoch [10/20], Step [401/915], Loss: 0.1123, Accuracy: 90.62%
# Epoch [10/20], Step [501/915], Loss: 0.2254, Accuracy: 78.12%
# Epoch [10/20], Step [601/915], Loss: 0.2014, Accuracy: 81.25%
# Epoch [10/20], Step [701/915], Loss: 0.2895, Accuracy: 68.75%
# Epoch [10/20], Step [801/915], Loss: 0.1792, Accuracy: 84.38%
# Epoch [10/20], Step [901/915], Loss: 0.1866, Accuracy: 81.25%
# Train Accuracy of the model on the train rna: 84.84703469492393 %
# Test Accuracy of the model on the test rna: 79.60506016661523 %
# Epoch [11/20], Step [1/915], Loss: 0.1278, Accuracy: 87.50%
# Epoch [11/20], Step [101/915], Loss: 0.2911, Accuracy: 68.75%
# Epoch [11/20], Step [201/915], Loss: 0.1311, Accuracy: 87.50%
# Epoch [11/20], Step [301/915], Loss: 0.1276, Accuracy: 87.50%
# Epoch [11/20], Step [401/915], Loss: 0.1789, Accuracy: 84.38%
# Epoch [11/20], Step [501/915], Loss: 0.2628, Accuracy: 71.88%
# Epoch [11/20], Step [601/915], Loss: 0.2700, Accuracy: 71.88%
# Epoch [11/20], Step [701/915], Loss: 0.2042, Accuracy: 84.38%
# Epoch [11/20], Step [801/915], Loss: 0.2541, Accuracy: 75.00%
# Epoch [11/20], Step [901/915], Loss: 0.3424, Accuracy: 62.50%
# Train Accuracy of the model on the train rna: 85.44180481968894 %
# Test Accuracy of the model on the test rna: 79.97531626041345 %
# Epoch [12/20], Step [1/915], Loss: 0.2034, Accuracy: 81.25%
# Epoch [12/20], Step [101/915], Loss: 0.1297, Accuracy: 87.50%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-321c2f21086e> in <module>
#       2 train_acc = []
#       3 test_acc = []
# ----> 4 train(cnntrans)
#
# <ipython-input-12-c50ebdc5f064> in train(model)
#       4     for epoch in range(num_epoch):
#       5         model.train()
# ----> 6         for i, batch in enumerate(train_loader):
#       7             # Run the forward pass
#       8             rna,labels = batch["rna"], batch["label"]
#
# ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     361
#     362     def __next__(self):
# --> 363         data = self._next_data()
#     364         self._num_yielded += 1
#     365         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     401     def _next_data(self):
#     402         index = self._next_index()  # may raise StopIteration
# --> 403         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     404         if self._pin_memory:
#     405             data = _utils.pin_memory.pin_memory(data)
#
# ~\anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~\anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-5-e92afd26a43f> in __getitem__(self, idx)
#      15         rna = self.data.iloc[idx]
#      16         seplb = self.label.iloc[idx]
# ---> 17         rna = np.array([rna])
#      18         seplb = np.array([seplb])
#      19         rna = rna.astype('double').reshape(-1,3273)
#
# KeyboardInterrupt:

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(train_acc, label='Training accuracy')
plt.legend()
plt.show()

# %%
#plt.plot(train_acc[200:], label='Training accuracy')
plt.legend()
plt.show()

# %%
# Save the model and plot
torch.save(model.state_dict(), MODEL_STORE_PATH + 'conv_net_model.ckpt')
