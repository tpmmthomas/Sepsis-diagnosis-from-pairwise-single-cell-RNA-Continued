# %%
# importing the libraries
import pandas as pd
import numpy as np
import os

# for reading and displaying images
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline

# for creating validation set
from sklearn.model_selection import train_test_split

# for evaluating the model
from sklearn.metrics import accuracy_score
from tqdm import tqdm

# PyTorch libraries and modules
import torch
from torch.autograd import Variable
import torch.nn as nn
from torch.optim import Adam, SGD
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import *
#Transformers
from module import *

# %%
# Load training data set (small amount to test if it works first)

xtrain = r"data/training_sample_NoSparse.csv.gz"
ytrain = r"data/training_label_NoSparse.csv.gz"
xtest = r"data/testing_sample_NoSparse.csv.gz"
ytest = r"data/testing_label_NoSparse.csv.gz"

# %%
#check balance
samplesdf = pd.DataFrame()
for df in  pd.read_csv(ytrain,compression ="gzip",delimiter=',', chunksize = 10000, header=0):
    samplesdf = samplesdf.append(df)
y_train = samplesdf.to_numpy()

num0 = 0
num1 = 0
for x in y_train:
    if x == 0:
        num0 = num0 + 1
    else:
        num1 = num1 + 1
num0,num1 #checking if it is balanced
# Out:
# (15161, 14094)

# %%
df = pd.read_csv(xtrain,compression ="gzip",delimiter=',', nrows=123, header=0)
x_train = df.to_numpy()
print(x_train)
# Out:
# [[0.   0.   0.   ... 3.11 0.   3.69]
#  [0.   0.   0.   ... 3.16 0.   3.33]
#  [0.   0.   0.   ... 2.98 0.   3.64]
#  ...
#  [1.39 0.   0.   ... 1.95 0.   3.57]
#  [0.   2.08 0.   ... 2.71 0.   3.09]
#  [0.   0.   0.   ... 3.12 0.   2.85]]

# %%
class Dataset(Dataset):

    def __init__(self,samples,labels,numrows):

        self.data = pd.read_csv(samples,compression ="gzip",delimiter=',', nrows = numrows, header=0)
        self.label = pd.read_csv(labels,compression ="gzip",delimiter=',', nrows = numrows, header=0)
        
    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        rna = self.data.iloc[idx]
        seplb = self.label.iloc[idx]
        rna = np.array([rna])
        seplb = np.array([seplb])
        rna = rna.astype('double').reshape(-1,3273)
        i = 0
        d = np.zeros((len(seplb),2))
        for x in seplb:
            if x == 0:
                d[i] = [1,0]
            else:
                d[i] = [0,1]
        sample = {'rna': rna, 'label': d}

        return sample

# %%
train_dataset = Dataset(samples=xtrain,labels=ytrain,numrows = 29255)
test_dataset = Dataset(samples = xtest,labels = ytest,numrows = 3241)

# %%
# Hyper Parameters
EPOCH = 20             # train the training data n times, to save time, we just train 1 epoch
LR = 0.0001              # learning rate
batch_size = 32
wd = LR / EPOCH

# %%
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(         # input shape (x,1, 8949)
            nn.Conv1d(
                in_channels=1,              # input height
                out_channels=4,            # n_filters
                kernel_size=3,              # filter size
                stride=1,                   # filter movement/step
                padding=1,                  # if want same width and length of this image after con2d, padding=(kernel_size-1)/2 if stride=1
            ),                              # output shape (x,64,8949)
            nn.BatchNorm1d(4),
            nn.ReLU(),                      # activation
        )
        self.conv2 = nn.Sequential(         # input shape (x,64, 8949)
            nn.Conv1d(4,4,3,1,1),            
            nn.ReLU(),  
            nn.Dropout(p=0.1),
            nn.MaxPool1d(kernel_size =2, stride=2,ceil_mode = True),                # output shape (x,64,4478)
        )
        self.conv3 = nn.Sequential(         # input shape (x,64,4478)
            nn.Conv1d(4, 4, 3, 1, 1),     # output shape (x,128,4478)
            nn.ReLU(),                      # activation
            nn.MaxPool1d(kernel_size =2, stride=2,ceil_mode = True),                # output shape (x,128,2238)
        )
        self.out = nn.Linear(3276 , 2)   # fully connected layer, output 10 classes

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = x.view(x.size(0), -1)
        output = self.out(x)
        return output

# %%
cnn = CNN()
optimizer = torch.optim.Adam(cnn.parameters(), lr=LR)   # optimize all cnn parameters
loss_func = nn.L1Loss()                      
if torch.cuda.is_available():
    cnn = cnn.cuda()
    loss_func = loss_func.cuda()
cnn = cnn.double()    
print(cnn)
# Out:
# CNN(
#   (conv1): Sequential(
#     (0): Conv1d(1, 4, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv2): Sequential(
#     (0): Conv1d(4, 4, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   )
#   (conv3): Sequential(
#     (0): Conv1d(4, 4, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   )
#   (out): Linear(in_features=3276, out_features=2, bias=True)
# )

# %%
def test(model):
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for batch in train_loader:
            rna,labels = batch["rna"], batch["label"] 
            if torch.cuda.is_available():
                rna = rna.cuda()
                labels = labels.cuda()
            labels = labels.reshape(-1,2)
            outputs = model(rna)
            outputs = outputs.reshape(-1,2)
            _, predicted = torch.max(outputs.data, 1)
            _, labels = torch.max(labels.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
           # print(total,correct)
        TrainaccTest.append(correct/total)
        
        print('Train Accuracy of the model on the train rna: {} %'.format((correct / total) * 100))
    with torch.no_grad():
        correct = 0
        total = 0
        for batch in test_loader:
            rna,labels = batch["rna"], batch["label"] 
            if torch.cuda.is_available():
                rna = rna.cuda()
                labels = labels.cuda()
            labels = labels.reshape(-1,2)
            outputs = model(rna)
            outputs = outputs.reshape(-1,2)
            _, predicted = torch.max(outputs.data, 1)
            _, labels = torch.max(labels.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    #print(total,correct)
        TestaccTest.append(correct/total)
        print('Test Accuracy of the model on the test rna: {} %'.format((correct / total) * 100))

# %%
def train(model): 
    total_step = len(train_loader)
    num_epoch = EPOCH
    for epoch in range(num_epoch):
        model.train()
        for i, batch in enumerate(train_loader):
            # Run the forward pass
            rna,labels = batch["rna"], batch["label"] 
            if torch.cuda.is_available():
                rna = rna.cuda()
                labels = labels.cuda()
            outputs = model(rna)
            labels = labels.long()
            #print(outputs)
            outputs = outputs.reshape(-1,2)
            labels = labels.reshape(-1,2)
            loss = loss_func(outputs, labels)
            train_losses.append(loss.item())

            # Backprop and perform Adam optimisation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Track the accuracy
            total = labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            _, labels = torch.max(labels.data, 1)
            correct = (predicted == labels).sum().item()
            train_acc.append(correct / total)
            if i % 100 == 0:
                print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                        .format(epoch + 1, num_epoch , i + 1, total_step, loss.item(),
                                (correct / total) * 100))
        test(model)

# %%
train_losses = []
train_acc = []
test_acc = []
TrainaccTest = []
TestaccTest = []
train(cnn)
# Out:
# Epoch [1/20], Step [1/915], Loss: 0.5936, Accuracy: 50.00%
# Epoch [1/20], Step [101/915], Loss: 0.4906, Accuracy: 50.00%
# Epoch [1/20], Step [201/915], Loss: 0.5093, Accuracy: 43.75%
# Epoch [1/20], Step [301/915], Loss: 0.3795, Accuracy: 78.12%
# Epoch [1/20], Step [401/915], Loss: 0.4028, Accuracy: 59.38%
# Epoch [1/20], Step [501/915], Loss: 0.3030, Accuracy: 78.12%
# Epoch [1/20], Step [601/915], Loss: 0.3130, Accuracy: 87.50%
# Epoch [1/20], Step [701/915], Loss: 0.3209, Accuracy: 81.25%
# Epoch [1/20], Step [801/915], Loss: 0.4161, Accuracy: 62.50%
# Epoch [1/20], Step [901/915], Loss: 0.2605, Accuracy: 81.25%
# Train Accuracy of the model on the train rna: 71.30746880875064 %
# Test Accuracy of the model on the test rna: 70.93489663684048 %
# Epoch [2/20], Step [1/915], Loss: 0.3898, Accuracy: 65.62%
# Epoch [2/20], Step [101/915], Loss: 0.3383, Accuracy: 68.75%
# Epoch [2/20], Step [201/915], Loss: 0.4375, Accuracy: 56.25%
# Epoch [2/20], Step [301/915], Loss: 0.3632, Accuracy: 71.88%
# Epoch [2/20], Step [401/915], Loss: 0.3204, Accuracy: 75.00%
# Epoch [2/20], Step [501/915], Loss: 0.3449, Accuracy: 65.62%
# Epoch [2/20], Step [601/915], Loss: 0.3359, Accuracy: 71.88%
# Epoch [2/20], Step [701/915], Loss: 0.3056, Accuracy: 75.00%
# Epoch [2/20], Step [801/915], Loss: 0.3447, Accuracy: 68.75%
# Epoch [2/20], Step [901/915], Loss: 0.3236, Accuracy: 81.25%
# Train Accuracy of the model on the train rna: 73.50538369509485 %
# Test Accuracy of the model on the test rna: 73.15643319962975 %
# Epoch [3/20], Step [1/915], Loss: 0.2584, Accuracy: 90.62%
# Epoch [3/20], Step [101/915], Loss: 0.3925, Accuracy: 59.38%
# Epoch [3/20], Step [201/915], Loss: 0.3350, Accuracy: 75.00%
# Epoch [3/20], Step [301/915], Loss: 0.3634, Accuracy: 65.62%
# Epoch [3/20], Step [401/915], Loss: 0.3371, Accuracy: 81.25%
# Epoch [3/20], Step [501/915], Loss: 0.3564, Accuracy: 78.12%
# Epoch [3/20], Step [601/915], Loss: 0.4445, Accuracy: 59.38%
# Epoch [3/20], Step [701/915], Loss: 0.2748, Accuracy: 90.62%
# Epoch [3/20], Step [801/915], Loss: 0.3141, Accuracy: 75.00%
# Epoch [3/20], Step [901/915], Loss: 0.2968, Accuracy: 75.00%
# Train Accuracy of the model on the train rna: 74.7598701076739 %
# Test Accuracy of the model on the test rna: 74.26720148102437 %
# Epoch [4/20], Step [1/915], Loss: 0.3491, Accuracy: 62.50%
# Epoch [4/20], Step [101/915], Loss: 0.2828, Accuracy: 87.50%
# Epoch [4/20], Step [201/915], Loss: 0.2718, Accuracy: 84.38%
# Epoch [4/20], Step [301/915], Loss: 0.3390, Accuracy: 71.88%
# Epoch [4/20], Step [401/915], Loss: 0.3056, Accuracy: 78.12%
# Epoch [4/20], Step [501/915], Loss: 0.3290, Accuracy: 75.00%
# Epoch [4/20], Step [601/915], Loss: 0.4083, Accuracy: 62.50%
# Epoch [4/20], Step [701/915], Loss: 0.2568, Accuracy: 84.38%
# Epoch [4/20], Step [801/915], Loss: 0.3519, Accuracy: 68.75%
# Epoch [4/20], Step [901/915], Loss: 0.4099, Accuracy: 62.50%
# Train Accuracy of the model on the train rna: 76.03828405400786 %
# Test Accuracy of the model on the test rna: 74.91514964517124 %
# Epoch [5/20], Step [1/915], Loss: 0.3641, Accuracy: 75.00%
# Epoch [5/20], Step [101/915], Loss: 0.2564, Accuracy: 87.50%
# Epoch [5/20], Step [201/915], Loss: 0.3646, Accuracy: 71.88%
# Epoch [5/20], Step [301/915], Loss: 0.3796, Accuracy: 68.75%
# Epoch [5/20], Step [401/915], Loss: 0.3816, Accuracy: 65.62%
# Epoch [5/20], Step [501/915], Loss: 0.3580, Accuracy: 71.88%
# Epoch [5/20], Step [601/915], Loss: 0.3315, Accuracy: 71.88%
# Epoch [5/20], Step [701/915], Loss: 0.2803, Accuracy: 84.38%
# Epoch [5/20], Step [801/915], Loss: 0.2846, Accuracy: 78.12%
# Epoch [5/20], Step [901/915], Loss: 0.3496, Accuracy: 75.00%
# Train Accuracy of the model on the train rna: 77.12527773030251 %
# Test Accuracy of the model on the test rna: 76.55044739278 %
# Epoch [6/20], Step [1/915], Loss: 0.2697, Accuracy: 78.12%
# Epoch [6/20], Step [101/915], Loss: 0.3770, Accuracy: 71.88%
# Epoch [6/20], Step [201/915], Loss: 0.2783, Accuracy: 81.25%
# Epoch [6/20], Step [301/915], Loss: 0.3278, Accuracy: 78.12%
# Epoch [6/20], Step [401/915], Loss: 0.2324, Accuracy: 90.62%
# Epoch [6/20], Step [501/915], Loss: 0.2582, Accuracy: 90.62%
# Epoch [6/20], Step [601/915], Loss: 0.3091, Accuracy: 78.12%
# Epoch [6/20], Step [701/915], Loss: 0.3160, Accuracy: 78.12%
# Epoch [6/20], Step [801/915], Loss: 0.2292, Accuracy: 87.50%
# Epoch [6/20], Step [901/915], Loss: 0.3782, Accuracy: 78.12%
# Train Accuracy of the model on the train rna: 78.02768757477354 %
# Test Accuracy of the model on the test rna: 77.13668620796051 %
# Epoch [7/20], Step [1/915], Loss: 0.3746, Accuracy: 71.88%
# Epoch [7/20], Step [101/915], Loss: 0.3041, Accuracy: 71.88%
# Epoch [7/20], Step [201/915], Loss: 0.3054, Accuracy: 78.12%
# Epoch [7/20], Step [301/915], Loss: 0.3625, Accuracy: 71.88%
# Epoch [7/20], Step [401/915], Loss: 0.2862, Accuracy: 81.25%
# Epoch [7/20], Step [501/915], Loss: 0.2810, Accuracy: 81.25%
# Epoch [7/20], Step [601/915], Loss: 0.2671, Accuracy: 81.25%
# Epoch [7/20], Step [701/915], Loss: 0.2997, Accuracy: 84.38%
# Epoch [7/20], Step [801/915], Loss: 0.3418, Accuracy: 75.00%
# Epoch [7/20], Step [901/915], Loss: 0.2775, Accuracy: 84.38%
# Train Accuracy of the model on the train rna: 78.66005810972483 %
# Test Accuracy of the model on the test rna: 78.1240357914224 %
# Epoch [8/20], Step [1/915], Loss: 0.2575, Accuracy: 84.38%
# Epoch [8/20], Step [101/915], Loss: 0.3305, Accuracy: 81.25%
# Epoch [8/20], Step [201/915], Loss: 0.3721, Accuracy: 62.50%
# Epoch [8/20], Step [301/915], Loss: 0.2750, Accuracy: 87.50%
# Epoch [8/20], Step [401/915], Loss: 0.3508, Accuracy: 68.75%
# Epoch [8/20], Step [501/915], Loss: 0.3405, Accuracy: 75.00%
# Epoch [8/20], Step [601/915], Loss: 0.3424, Accuracy: 75.00%
# Epoch [8/20], Step [701/915], Loss: 0.3224, Accuracy: 75.00%
# Epoch [8/20], Step [801/915], Loss: 0.2870, Accuracy: 78.12%
# Epoch [8/20], Step [901/915], Loss: 0.2669, Accuracy: 90.62%
# Train Accuracy of the model on the train rna: 79.42573918988207 %
# Test Accuracy of the model on the test rna: 78.61771058315334 %
# Epoch [9/20], Step [1/915], Loss: 0.4032, Accuracy: 59.38%
# Epoch [9/20], Step [101/915], Loss: 0.2566, Accuracy: 81.25%
# Epoch [9/20], Step [201/915], Loss: 0.3467, Accuracy: 75.00%
# Epoch [9/20], Step [301/915], Loss: 0.2571, Accuracy: 87.50%
# Epoch [9/20], Step [401/915], Loss: 0.3273, Accuracy: 81.25%
# Epoch [9/20], Step [501/915], Loss: 0.2813, Accuracy: 78.12%
# Epoch [9/20], Step [601/915], Loss: 0.2445, Accuracy: 90.62%
# Epoch [9/20], Step [701/915], Loss: 0.3617, Accuracy: 68.75%
# Epoch [9/20], Step [801/915], Loss: 0.3367, Accuracy: 71.88%
# Epoch [9/20], Step [901/915], Loss: 0.3228, Accuracy: 75.00%
# Train Accuracy of the model on the train rna: 79.4120663134507 %
# Test Accuracy of the model on the test rna: 78.40172786177105 %
# Epoch [10/20], Step [1/915], Loss: 0.3419, Accuracy: 71.88%
# Epoch [10/20], Step [101/915], Loss: 0.2610, Accuracy: 84.38%
# Epoch [10/20], Step [201/915], Loss: 0.3248, Accuracy: 71.88%
# Epoch [10/20], Step [301/915], Loss: 0.3545, Accuracy: 75.00%
# Epoch [10/20], Step [401/915], Loss: 0.2227, Accuracy: 87.50%
# Epoch [10/20], Step [501/915], Loss: 0.2319, Accuracy: 87.50%
# Epoch [10/20], Step [601/915], Loss: 0.2572, Accuracy: 81.25%
# Epoch [10/20], Step [701/915], Loss: 0.2438, Accuracy: 87.50%
# Epoch [10/20], Step [801/915], Loss: 0.3672, Accuracy: 68.75%
# Epoch [10/20], Step [901/915], Loss: 0.2898, Accuracy: 81.25%
# Train Accuracy of the model on the train rna: 79.4120663134507 %
# Test Accuracy of the model on the test rna: 78.34001851280469 %
# Epoch [11/20], Step [1/915], Loss: 0.2020, Accuracy: 96.88%
# Epoch [11/20], Step [101/915], Loss: 0.2651, Accuracy: 87.50%
# Epoch [11/20], Step [201/915], Loss: 0.3208, Accuracy: 84.38%
# Epoch [11/20], Step [301/915], Loss: 0.2501, Accuracy: 87.50%
# Epoch [11/20], Step [401/915], Loss: 0.3011, Accuracy: 84.38%
# Epoch [11/20], Step [501/915], Loss: 0.2724, Accuracy: 84.38%
# Epoch [11/20], Step [601/915], Loss: 0.2853, Accuracy: 81.25%
# Epoch [11/20], Step [701/915], Loss: 0.3050, Accuracy: 84.38%
# Epoch [11/20], Step [801/915], Loss: 0.2196, Accuracy: 90.62%
# Epoch [11/20], Step [901/915], Loss: 0.2576, Accuracy: 84.38%
# Train Accuracy of the model on the train rna: 79.90770808408818 %
# Test Accuracy of the model on the test rna: 79.11138537488429 %
# Epoch [12/20], Step [1/915], Loss: 0.2930, Accuracy: 75.00%
# Epoch [12/20], Step [101/915], Loss: 0.3556, Accuracy: 65.62%
# Epoch [12/20], Step [201/915], Loss: 0.3257, Accuracy: 75.00%
# Epoch [12/20], Step [301/915], Loss: 0.3722, Accuracy: 68.75%
# Epoch [12/20], Step [401/915], Loss: 0.2516, Accuracy: 87.50%
# Epoch [12/20], Step [501/915], Loss: 0.3412, Accuracy: 75.00%
# Epoch [12/20], Step [601/915], Loss: 0.2751, Accuracy: 84.38%
# Epoch [12/20], Step [701/915], Loss: 0.3350, Accuracy: 75.00%
# Epoch [12/20], Step [801/915], Loss: 0.3018, Accuracy: 84.38%
# Epoch [12/20], Step [901/915], Loss: 0.2376, Accuracy: 93.75%
# Train Accuracy of the model on the train rna: 80.76568108015724 %
# Test Accuracy of the model on the test rna: 79.51249614316569 %
# Epoch [13/20], Step [1/915], Loss: 0.3149, Accuracy: 75.00%
# Epoch [13/20], Step [101/915], Loss: 0.4089, Accuracy: 65.62%
# Epoch [13/20], Step [201/915], Loss: 0.3301, Accuracy: 68.75%
# Epoch [13/20], Step [301/915], Loss: 0.2816, Accuracy: 87.50%
# Epoch [13/20], Step [401/915], Loss: 0.3152, Accuracy: 75.00%
# Epoch [13/20], Step [501/915], Loss: 0.3295, Accuracy: 71.88%
# Epoch [13/20], Step [601/915], Loss: 0.2699, Accuracy: 84.38%
# Epoch [13/20], Step [701/915], Loss: 0.2198, Accuracy: 93.75%
# Epoch [13/20], Step [801/915], Loss: 0.3404, Accuracy: 75.00%
# Epoch [13/20], Step [901/915], Loss: 0.3351, Accuracy: 78.12%
# Train Accuracy of the model on the train rna: 81.0220475132456 %
# Test Accuracy of the model on the test rna: 80.00617093489663 %
# Epoch [14/20], Step [1/915], Loss: 0.2790, Accuracy: 81.25%
# Epoch [14/20], Step [101/915], Loss: 0.2420, Accuracy: 90.62%
# Epoch [14/20], Step [201/915], Loss: 0.2485, Accuracy: 81.25%
# Epoch [14/20], Step [301/915], Loss: 0.3454, Accuracy: 71.88%
# Epoch [14/20], Step [401/915], Loss: 0.3565, Accuracy: 75.00%
# Epoch [14/20], Step [501/915], Loss: 0.2983, Accuracy: 84.38%
# Epoch [14/20], Step [601/915], Loss: 0.3132, Accuracy: 75.00%
# Epoch [14/20], Step [701/915], Loss: 0.2489, Accuracy: 87.50%
# Epoch [14/20], Step [801/915], Loss: 0.3056, Accuracy: 78.12%
# Epoch [14/20], Step [901/915], Loss: 0.3075, Accuracy: 87.50%
# Train Accuracy of the model on the train rna: 81.21688600239276 %
# Test Accuracy of the model on the test rna: 79.94446158593027 %
# Epoch [15/20], Step [1/915], Loss: 0.2696, Accuracy: 81.25%
# Epoch [15/20], Step [101/915], Loss: 0.3688, Accuracy: 75.00%
# Epoch [15/20], Step [201/915], Loss: 0.3011, Accuracy: 75.00%
# Epoch [15/20], Step [301/915], Loss: 0.3525, Accuracy: 68.75%
# Epoch [15/20], Step [401/915], Loss: 0.2568, Accuracy: 81.25%
# Epoch [15/20], Step [501/915], Loss: 0.2795, Accuracy: 84.38%
# Epoch [15/20], Step [601/915], Loss: 0.2892, Accuracy: 75.00%
# Epoch [15/20], Step [701/915], Loss: 0.2935, Accuracy: 84.38%
# Epoch [15/20], Step [801/915], Loss: 0.2681, Accuracy: 90.62%
# Epoch [15/20], Step [901/915], Loss: 0.3603, Accuracy: 71.88%
# Train Accuracy of the model on the train rna: 81.42881558707913 %
# Test Accuracy of the model on the test rna: 80.49984572662758 %
# Epoch [16/20], Step [1/915], Loss: 0.2818, Accuracy: 90.62%
# Epoch [16/20], Step [101/915], Loss: 0.3554, Accuracy: 75.00%
# Epoch [16/20], Step [201/915], Loss: 0.3481, Accuracy: 68.75%
# Epoch [16/20], Step [301/915], Loss: 0.3172, Accuracy: 78.12%
# Epoch [16/20], Step [401/915], Loss: 0.2805, Accuracy: 84.38%
# Epoch [16/20], Step [501/915], Loss: 0.2694, Accuracy: 87.50%
# Epoch [16/20], Step [601/915], Loss: 0.2307, Accuracy: 84.38%
# Epoch [16/20], Step [701/915], Loss: 0.3079, Accuracy: 78.12%
# Epoch [16/20], Step [801/915], Loss: 0.2831, Accuracy: 78.12%
# Epoch [16/20], Step [901/915], Loss: 0.3397, Accuracy: 78.12%
# Train Accuracy of the model on the train rna: 81.6407451717655 %
# Test Accuracy of the model on the test rna: 80.40728170317803 %
# Epoch [17/20], Step [1/915], Loss: 0.3341, Accuracy: 75.00%
# Epoch [17/20], Step [101/915], Loss: 0.3124, Accuracy: 81.25%
# Epoch [17/20], Step [201/915], Loss: 0.2174, Accuracy: 87.50%
# Epoch [17/20], Step [301/915], Loss: 0.3413, Accuracy: 87.50%
# Epoch [17/20], Step [401/915], Loss: 0.3297, Accuracy: 78.12%
# Epoch [17/20], Step [501/915], Loss: 0.2859, Accuracy: 81.25%
# Epoch [17/20], Step [601/915], Loss: 0.3291, Accuracy: 78.12%
# Epoch [17/20], Step [701/915], Loss: 0.3023, Accuracy: 75.00%
# Epoch [17/20], Step [801/915], Loss: 0.2865, Accuracy: 81.25%
# Epoch [17/20], Step [901/915], Loss: 0.3251, Accuracy: 71.88%
# Train Accuracy of the model on the train rna: 81.8082379080499 %
# Test Accuracy of the model on the test rna: 80.56155507559394 %
# Epoch [18/20], Step [1/915], Loss: 0.2269, Accuracy: 84.38%
# Epoch [18/20], Step [101/915], Loss: 0.2555, Accuracy: 84.38%
# Epoch [18/20], Step [201/915], Loss: 0.2942, Accuracy: 81.25%
# Epoch [18/20], Step [301/915], Loss: 0.2312, Accuracy: 90.62%
# Epoch [18/20], Step [401/915], Loss: 0.2680, Accuracy: 93.75%
# Epoch [18/20], Step [501/915], Loss: 0.2647, Accuracy: 81.25%
# Epoch [18/20], Step [601/915], Loss: 0.3639, Accuracy: 71.88%
# Epoch [18/20], Step [701/915], Loss: 0.2851, Accuracy: 84.38%
# Epoch [18/20], Step [801/915], Loss: 0.3147, Accuracy: 81.25%
# Epoch [18/20], Step [901/915], Loss: 0.3356, Accuracy: 71.88%
# Train Accuracy of the model on the train rna: 82.11587762775594 %
# Test Accuracy of the model on the test rna: 80.80839247145943 %
# Epoch [19/20], Step [1/915], Loss: 0.2897, Accuracy: 87.50%
# Epoch [19/20], Step [101/915], Loss: 0.3069, Accuracy: 78.12%
# Epoch [19/20], Step [201/915], Loss: 0.3305, Accuracy: 75.00%
# Epoch [19/20], Step [301/915], Loss: 0.2845, Accuracy: 87.50%
# Epoch [19/20], Step [401/915], Loss: 0.3075, Accuracy: 78.12%
# Epoch [19/20], Step [501/915], Loss: 0.2426, Accuracy: 87.50%
# Epoch [19/20], Step [601/915], Loss: 0.3244, Accuracy: 78.12%
# Epoch [19/20], Step [701/915], Loss: 0.2695, Accuracy: 84.38%
# Epoch [19/20], Step [801/915], Loss: 0.2735, Accuracy: 87.50%
# Epoch [19/20], Step [901/915], Loss: 0.3094, Accuracy: 84.38%
# Train Accuracy of the model on the train rna: 82.0680225602461 %
# Test Accuracy of the model on the test rna: 80.37642702869485 %
# Epoch [20/20], Step [1/915], Loss: 0.3144, Accuracy: 75.00%
# Epoch [20/20], Step [101/915], Loss: 0.2887, Accuracy: 84.38%
# Epoch [20/20], Step [201/915], Loss: 0.3578, Accuracy: 71.88%
# Epoch [20/20], Step [301/915], Loss: 0.3210, Accuracy: 78.12%
# Epoch [20/20], Step [401/915], Loss: 0.2654, Accuracy: 90.62%
# Epoch [20/20], Step [501/915], Loss: 0.2546, Accuracy: 75.00%
# Epoch [20/20], Step [601/915], Loss: 0.2971, Accuracy: 81.25%
# Epoch [20/20], Step [701/915], Loss: 0.2492, Accuracy: 87.50%
# Epoch [20/20], Step [801/915], Loss: 0.2716, Accuracy: 87.50%
# Epoch [20/20], Step [901/915], Loss: 0.2987, Accuracy: 87.50%
# Train Accuracy of the model on the train rna: 82.54657323534438 %
# Test Accuracy of the model on the test rna: 81.08608454180808 %

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(train_acc, label='Training accuracy')
plt.legend()
plt.show()

# %%
plt.plot(TrainaccTest, label='Training loss')
plt.plot(TestaccTest, label='Training accuracy')
plt.legend()
plt.show()

# %%
samplesdf = pd.DataFrame()
samplesdf = pd.read_csv(xtest,compression ="gzip",delimiter=',',header=0)
x_test = samplesdf.to_numpy()

samplesdf = pd.DataFrame()
samplesdf = pd.read_csv(ytest,compression ="gzip",delimiter=',', header=0)
y_test = samplesdf.to_numpy()

x_test = torch.from_numpy(x_test)
y_test = torch.from_numpy(y_test)
print(x_test.shape)
print(y_test.shape)
with torch.no_grad():
    cnn = cnn.cpu()
    cnn.eval()

    x_test = x_test.reshape(-1,1,3273)
    outputs = cnn(x_test)
    out = outputs.data.reshape(-1,2)
    print(out)
    predicted = np.zeros((len(out)))
    i = 0
    for x in out:
        predicted[i] = x[1]
        i = i + 1
    print(predicted)
    y_test = y_test.cpu()
    y_test = y_test.reshape(-1)
    fpr, tpr, _ = roc_curve(y_test,predicted)
    roc_auc = auc(fpr,tpr)
    plt.figure()
    lw = 2
    plt.plot(fpr,tpr, color='darkorange',
             lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('AUROC curve for CNN')
    plt.legend(loc="lower right")
    plt.show()
    precision, recall, _ = precision_recall_curve(y_test,predicted)
    prc_auc = auc(recall,precision)
    plt.plot(recall,precision, color='darkorange',
             lw=lw, label='PRC curve (area = %0.2f)' % prc_auc)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('AUPRC curve for CNN')
    plt.legend(loc="lower right")
    plt.show()
    print("AUPRC = %.02f"% prc_auc)
    ss = np.zeros((len(predicted)))
    i = 0
    for x in predicted:
        if x >= 0.5:
            ss[i] = 1
        else:
            ss[i] = 0
        i = i + 1
    f1s = f1_score(y_test,ss)
    print("f1_score = %.02f"% f1s)
    df = pd.DataFrame(y_test)
    df.to_csv(r"data/cnnlb.csv.gz",index=False,sep=",",compression="gzip")
    df = pd.DataFrame(predicted)
    df.to_csv(r"data/cnnpredict.csv.gz",index=False,sep=",",compression="gzip")
# Out:
# torch.Size([3241, 3273])
# torch.Size([3241, 1])
# tensor([[ 0.9225, -0.0036],
#         [ 0.2518,  0.6757],
#         [ 0.7596,  0.1750],
#         ...,
#         [ 0.5899,  0.3431],
#         [ 1.0399, -0.1183],
#         [ 0.7260,  0.1862]], dtype=torch.float64)
# [-0.00362817  0.67568441  0.17500183 ...  0.34308637 -0.11825361
#   0.18616685]
# AUPRC = 0.89
# f1_score = 0.80
